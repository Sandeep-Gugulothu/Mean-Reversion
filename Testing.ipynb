# %% [markdown]
# # Mean Reversion Trading Strategy — Per-Stock Analysis
# Strategy applied **independently** on each NIFTY 50 stock using its own close price.

# %% [markdown]
# ## 1. Load & Clean Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# NOTE: removed warnings.filterwarnings('ignore') — want to see real warnings
# e.g. division by zero in z-score when sigma=0

df  = pd.read_csv('data/nifty50_close.csv', parse_dates=['Date'], index_col='Date')
idx = pd.read_csv('data/nifty50_index.csv', parse_dates=['Date'], index_col='Date')

df  = df.ffill().dropna()
idx = idx.ffill().dropna()
common = df.index.intersection(idx.index)
df, idx = df.loc[common], idx.loc[common]

STOCKS = df.columns.tolist()
print(f"Stocks: {len(STOCKS)} | Days: {len(df)} | {df.index[0].date()} → {df.index[-1].date()}")
print(STOCKS)

# NOTE: survivorship bias — this is the *current* NIFTY 50 list.
# Stocks removed from the index over the past 5 years are not included.
# This likely overstates backtest returns. Noted as a limitation.
# Out:
# Stocks: 49 | Days: 1235 | 2021-06-01 → 2026-06-01
# ['KOTAKBANK', 'M&M', 'ADANIENT', 'APOLLOHOSP', 'VEDL', 'HCLTECH', 'RELIANCE', 'SHREECEM', 'UPL', 'HEROMOTOCO', 'BPCL', 'TITAN', 'SUNPHARMA', 'INDUSINDBK', 'MARUTI', 'HINDUNILVR', 'NESTLEIND', 'HDFCBANK', 'DIVISLAB', 'DRREDDY', 'ITC', 'ADANIPORTS', 'INFY', 'AXISBANK', 'BRITANNIA', 'HINDALCO', 'BHARTIARTL', 'BAJFINANCE', 'NTPC', 'ICICIBANK', 'COALINDIA', 'WIPRO', 'TATACONSUM', 'CIPLA', 'SBIN', 'LT', 'JSWSTEEL', 'ULTRACEMCO', 'POWERGRID', 'ONGC', 'IOC', 'TATASTEEL', 'EICHERMOT', 'BAJAJFINSV', 'GRASIM', 'ASIANPAINT', 'TECHM', 'BAJAJ-AUTO', 'TCS']

# %% [markdown]
# ## 2. Strategy Parameters

# %%
WINDOW      = 20      # rolling z-score window
BUY_Z       = -2.0    # enter long when z < BUY_Z
SELL_Z      =  2.0    # enter short when z > SELL_Z
HOLD_DAYS   =  5      # hold each position for 5 days
COST        =  0.001  # one-way transaction cost (0.1%) — was 0.0, now realistic

# %% [markdown]
# ## 3. Per-Stock Backtest
# For each stock independently:
# 1. Compute daily returns from close price
# 2. Compute rolling 20-day z-score
# 3. Generate buy/sell signals and simulate 5-day holding period
# 4. Deduct transaction costs

# %%
def backtest_single(prices, window=WINDOW, buy_z=BUY_Z, sell_z=SELL_Z,
                    hold=HOLD_DAYS, cost=COST):
    """Run mean reversion strategy on a single stock's close price series."""
    ret   = prices.pct_change().dropna()
    mu    = ret.rolling(window).mean()
    sigma = ret.rolling(window).std()

    # FIX: avoid division by zero when sigma=0 (flat price periods)
    z = (ret - mu) / sigma.replace(0, np.nan)

    # FIX: vectorized signal generation with explicit 1-day lag (no lookahead)
    # signal on day t uses z-score from day t-1
    raw_signal = pd.Series(0, index=z.index)
    raw_signal[z.shift(1) < buy_z]  =  1
    raw_signal[z.shift(1) > sell_z] = -1

    # propagate position forward for hold days
    pos = raw_signal.copy().astype(float)
    for shift in range(1, hold):
        pos = pos + raw_signal.shift(shift).fillna(0)
    pos = pos.clip(-1, 1)  # first signal wins on overlap

    gross      = pos * ret
    trade_cost = pos.diff().abs() * cost
    net        = gross - trade_cost.fillna(0)

    return net, pos, z


def compute_metrics(daily_ret):
    daily_ret = daily_ret.dropna()
    equity   = (1 + daily_ret).cumprod()
    total    = equity.iloc[-1] - 1
    n_years  = len(daily_ret) / 252
    cagr     = (1 + total) ** (1 / n_years) - 1 if n_years > 0 else 0
    sharpe   = daily_ret.mean() / daily_ret.std() * np.sqrt(252) if daily_ret.std() > 0 else 0
    roll_max = equity.cummax()
    max_dd   = ((equity - roll_max) / roll_max).min()
    active   = daily_ret[daily_ret != 0]
    win_rate = (active > 0).mean() if len(active) > 0 else 0

    # FIX: count trades as position changes (pos.diff() != 0), not return toggles
    n_trades = 'computed_in_backtest'  # placeholder — see below

    return dict(total_ret=total, cagr=cagr, sharpe=sharpe,
                max_dd=max_dd, win_rate=win_rate, n_trades=n_trades, equity=equity)


# Run on every stock
results = {}
for stock in STOCKS:
    net_ret, pos, z = backtest_single(df[stock])
    metrics = compute_metrics(net_ret)
    # FIX: correct trade count — number of times position changes
    metrics['n_trades'] = int((pos.diff().fillna(0) != 0).sum())
    metrics['net_ret']  = net_ret
    results[stock] = metrics

print(f"Backtested {len(results)} stocks.")
# Out:
# Backtested 49 stocks.

# %% [markdown]
# ## 4. Per-Stock Performance Table

# %%
summary = pd.DataFrame({
    s: {
        'Total Return (%)' : round(results[s]['total_ret'] * 100, 2),
        'CAGR (%)'         : round(results[s]['cagr']      * 100, 2),
        'Sharpe Ratio'     : round(results[s]['sharpe'],           3),
        'Max Drawdown (%)'  : round(results[s]['max_dd']    * 100, 2),
        'Win Rate (%)'     : round(results[s]['win_rate']   * 100, 2),
        'Trades'           : results[s]['n_trades'],
    }
    for s in STOCKS
}).T

summary = summary.sort_values('Sharpe Ratio', ascending=False)
summary.index.name = 'Stock'

def colour(val):
    color = 'green' if val > 0 else 'red'
    return f'color: {color}'

display(summary.style
        .applymap(colour, subset=['CAGR (%)', 'Total Return (%)'])
        .format(precision=2)
        .set_caption('Mean Reversion Strategy — Per-Stock Results (sorted by Sharpe)'))
# Out:
# C:\Users\Sandeep\AppData\Local\Temp\ipykernel_15952\4021116733.py:21: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   .applymap(colour, subset=['CAGR (%)', 'Total Return (%)'])
# <style type="text/css">
# #T_872e4_row0_col0, #T_872e4_row0_col1, #T_872e4_row1_col0, #T_872e4_row1_col1, #T_872e4_row2_col0, #T_872e4_row2_col1, #T_872e4_row3_col0, #T_872e4_row3_col1, #T_872e4_row4_col0, #T_872e4_row4_col1, #T_872e4_row5_col0, #T_872e4_row5_col1, #T_872e4_row6_col0, #T_872e4_row6_col1, #T_872e4_row7_col0, #T_872e4_row7_col1, #T_872e4_row8_col0, #T_872e4_row8_col1, #T_872e4_row9_col0, #T_872e4_row9_col1, #T_872e4_row10_col0, #T_872e4_row10_col1, #T_872e4_row11_col0, #T_872e4_row11_col1, #T_872e4_row12_col0, #T_872e4_row12_col1, #T_872e4_row13_col0, #T_872e4_row13_col1, #T_872e4_row14_col0, #T_872e4_row14_col1, #T_872e4_row15_col0, #T_872e4_row15_col1 {
#   color: green;
# }
# #T_872e4_row16_col0, #T_872e4_row16_col1, #T_872e4_row17_col0, #T_872e4_row17_col1, #T_872e4_row18_col0, #T_872e4_row18_col1, #T_872e4_row19_col0, #T_872e4_row19_col1, #T_872e4_row20_col0, #T_872e4_row20_col1, #T_872e4_row21_col0, #T_872e4_row21_col1, #T_872e4_row22_col0, #T_872e4_row22_col1, #T_872e4_row23_col0, #T_872e4_row23_col1, #T_872e4_row24_col0, #T_872e4_row24_col1, #T_872e4_row25_col0, #T_872e4_row25_col1, #T_872e4_row26_col0, #T_872e4_row26_col1, #T_872e4_row27_col0, #T_872e4_row27_col1, #T_872e4_row28_col0, #T_872e4_row28_col1, #T_872e4_row29_col0, #T_872e4_row29_col1, #T_872e4_row30_col0, #T_872e4_row30_col1, #T_872e4_row31_col0, #T_872e4_row31_col1, #T_872e4_row32_col0, #T_872e4_row32_col1, #T_872e4_row33_col0, #T_872e4_row33_col1, #T_872e4_row34_col0, #T_872e4_row34_col1, #T_872e4_row35_col0, #T_872e4_row35_col1, #T_872e4_row36_col0, #T_872e4_row36_col1, #T_872e4_row37_col0, #T_872e4_row37_col1, #T_872e4_row38_col0, #T_872e4_row38_col1, #T_872e4_row39_col0, #T_872e4_row39_col1, #T_872e4_row40_col0, #T_872e4_row40_col1, #T_872e4_row41_col0, #T_872e4_row41_col1, #T_872e4_row42_col0, #T_872e4_row42_col1, #T_872e4_row43_col0, #T_872e4_row43_col1, #T_872e4_row44_col0, #T_872e4_row44_col1, #T_872e4_row45_col0, #T_872e4_row45_col1, #T_872e4_row46_col0, #T_872e4_row46_col1, #T_872e4_row47_col0, #T_872e4_row47_col1, #T_872e4_row48_col0, #T_872e4_row48_col1 {
#   color: red;
# }
# </style>
# <table id="T_872e4">
#   <caption>Mean Reversion Strategy — Per-Stock Results (sorted by Sharpe)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_872e4_level0_col0" class="col_heading level0 col0" >Total Return (%)</th>
#       <th id="T_872e4_level0_col1" class="col_heading level0 col1" >CAGR (%)</th>
#       <th id="T_872e4_level0_col2" class="col_heading level0 col2" >Sharpe Ratio</th>
#       <th id="T_872e4_level0_col3" class="col_heading level0 col3" >Max Drawdown (%)</th>
#       <th id="T_872e4_level0_col4" class="col_heading level0 col4" >Win Rate (%)</th>
#       <th id="T_872e4_level0_col5" class="col_heading level0 col5" >Trades</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Stock</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_872e4_level0_row0" class="row_heading level0 row0" >VEDL</th>
#       <td id="T_872e4_row0_col0" class="data row0 col0" >122.15</td>
#       <td id="T_872e4_row0_col1" class="data row0 col1" >17.70</td>
#       <td id="T_872e4_row0_col2" class="data row0 col2" >0.96</td>
#       <td id="T_872e4_row0_col3" class="data row0 col3" >-27.00</td>
#       <td id="T_872e4_row0_col4" class="data row0 col4" >48.11</td>
#       <td id="T_872e4_row0_col5" class="data row0 col5" >102.00</td>
#     </tr>
#     <tr>
#       <th id="T_872e4_level0_row1" class="row_heading level0 row1" >ONGC</th>
#       <td id="T_872e4_row1_col0" class="data row1 col0" >72.35</td>
#       <td id="T_872e4_row1_col1" class="data row1 col1" >11.76</td>
#       <td id="T_872e4_row1_col2" class="data row1 col2" >0.73</td>
#       <td id="T_872e4_row1_col3" class="data row1 col3" >-16.20</td>
#       <td id="T_872e4_row1_col4" class="data row1 col4" >43.51</td>
#       <td id="T_872e4_row1_col5" class="data row1 col5" >107.00</td>
#     </tr>
#     <tr>
#       <th id="T_872e4_level0_row2" class="row_heading level0 row2" >TATASTEEL</th>
#       <td id="T_872e4_row2_col0" class="data row2 col0" >73.25</td>
#       <td id="T_872e4_row2_col1" class="data row2 col1" >11.88</td>
#       <td id="T_872e4_row2_col2" class="data row2 col2" >0.73</td>
#       <td id="T_872e4_row2_col3" class="data row2 col3" >-19.65</td>
#       <td id="T_872e4_row2_col4" class="data row2 col4" >43.10</td>
#       <td id="T_872e4_row2_col5" class="data row2 col5" >119.00</td>
#     </tr>
#     <tr>
#       <th id="T_872e4_level0_row3" class="row_heading level0 row3" >BHARTIARTL</th>
#       <td id="T_872e4_row3_col0" class="data row3 col0" >45.27</td>
#       <td id="T_872e4_row3_col1" class="data row3 col1" >7.92</td>
#       <td id="T_872e4_row3_col2" class="data row3 col2" >0.71</td>
#       <td id="T_872e4_row3_col3" class="data row3 col3" >-10.03</td>
#       <td id="T_872e4_row3_col4" class="data row3 col4" >45.19</td>
#       <td id="T_872e4_row3_col5" class="data row3 col5" >103.00</td>
#     </tr>
#     <tr>
#       <th id="T_872e4_level0_row4" class="row_heading level0 row4" >COALINDIA</th>
#       <td id="T_872e4_row4_col0" class="data row4 col0" >52.84</td>
#       <td id="T_872e4_row4_col1" class="data row4 col1" >9.05</td>
#       <td id="T_872e4_row4_col2" class="data row4 col2" >0.66</td>
#       <td id="T_872e4_row4_col3" class="data row4 col3" >-25.73</td>
#       <td id="T_872e4_row4_col4" class="data row4 col4" >44.20</td>
#       <td id="T_872e4_row4_col5" class="data row4 col5" >114.00</td>
#     </tr>
#     <tr>
#       <th id="T_872e4_level0_row5" class="row_heading level0 row5" >JSWSTEEL</th>
#       <td id="T_872e4_row5_col0" class="data row5 col0" >42.43</td>
#       <td id="T_872e4_row5_col1" class="data row5 col1" >7.49</td>
#       <td id="T_872e4_row5_col2" class="data row5 col2" >0.56</td>
#       <td id="T_872e4_row5_col3" class="data row5 col3" >-24.27</td>
#       <td id="T_872e4_row5_col4" class="data row5 col4" >42.62</td>
#       <td id="T_872e4_row5_col5" class="data row5 col5" >109.00</td>
#     </tr>
#     <tr>
#       <th id="T_872e4_level0_row6" class="row_heading level0 row6" >HINDALCO</th>
#       <td id="T_872e4_row6_col0" class="data row6 col0" >37.97</td>
#       <td id="T_872e4_row6_col1" class="data row6 col1" >6.79</td>
#       <td id="T_872e4_row6_col2" class="data row6 col2" >0.52</td>
#       <td id="T_872e4_row6_col3" class="data row6 col3" >-16.33</td>
#       <td id="T_872e4_row6_col4" class="data row6 col4" >43.38</td>
#       <td id="T_872e4_row6_col5" class="data row6 col5" >105.00</td>
#     </tr>
#     <tr>
#       <th id="T_872e4_level0_row7" class="row_heading level0 row7" >GRASIM</th>
#       <td id="T_872e4_row7_col0" class="data row7 col0" >26.56</td>
#       <td id="T_872e4_row7_col1" class="data row7 col1" >4.93</td>
#       <td id="T_872e4_row7_col2" class="data row7 col2" >0.51</td>
#       <td id="T_872e4_row7_col3" class="data row7 col3" >-14.92</td>
#       <td id="T_872e4_row7_col4" class="data row7 col4" >43.48</td>
#       <td id="T_872e4_row7_col5" class="data row7 col5" >91.00</td>
#     </tr>
#     <tr>
#       <th id="T_872e4_level0_row8" class="row_heading level0 row8" >BPCL</th>
#       <td id="T_872e4_row8_col0" class="data row8 col0" >27.86</td>
#       <td id="T_872e4_row8_col1" class="data row8 col1" >5.15</td>
#       <td id="T_872e4_row8_col2" class="data row8 col2" >0.42</td>
#       <td id="T_872e4_row8_col3" class="data row8 col3" >-25.13</td>
#       <td id="T_872e4_row8_col4" class="data row8 col4" >44.76</td>
#       <td id="T_872e4_row8_col5" class="data row8 col5" >106.00</td>
#     </tr>
#     <tr>
#       <th id="T_872e4_level0_row9" class="row_heading level0 row9" >ICICIBANK</th>
#       <td id="T_872e4_row9_col0" class="data row9 col0" >17.81</td>
#       <td id="T_872e4_row9_col1" class="data row9 col1" >3.40</td>
#       <td id="T_872e4_row9_col2" class="data row9 col2" >0.4

# %% [markdown]
# ## 5. Benchmark Metrics (NIFTY 50 Buy & Hold)

# %%
# FIX: benchmark was already here but defining clearly so all cells below can use it
bm_ret    = idx.squeeze().pct_change().dropna()
bm_equity = (1 + bm_ret).cumprod()
bm_total  = bm_equity.iloc[-1] - 1
bm_nyears = len(bm_ret) / 252
bm_cagr   = (1 + bm_total) ** (1 / bm_nyears) - 1
bm_sharpe = bm_ret.mean() / bm_ret.std() * np.sqrt(252)

print(f"Benchmark (NIFTY 50 B&H) CAGR  : {bm_cagr*100:.2f}%")
print(f"Benchmark (NIFTY 50 B&H) Sharpe: {bm_sharpe:.3f}")
# Out:
# Benchmark (NIFTY 50 B&H) CAGR  : 8.65%
# Benchmark (NIFTY 50 B&H) Sharpe: 0.672

# %% [markdown]
# ## 6. Visualizations
# ### 6a. Equity Curves — Top 10 vs Bottom 10 Stocks

# %%
top10    = summary.head(10).index.tolist()
bottom10 = summary.tail(10).index.tolist()

fig, axes = plt.subplots(1, 2, figsize=(18, 6))
fig.suptitle('Equity Curves — Mean Reversion Strategy per Stock', fontsize=13, fontweight='bold')

for stock in top10:
    results[stock]['equity'].plot(ax=axes[0], label=stock, linewidth=1)
axes[0].set_title('Top 10 Stocks (by Sharpe)')
axes[0].set_ylabel('Portfolio Value (₹1 invested)')
axes[0].legend(fontsize=7, ncol=2)
axes[0].xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

for stock in bottom10:
    results[stock]['equity'].plot(ax=axes[1], label=stock, linewidth=1)
axes[1].set_title('Bottom 10 Stocks (by Sharpe)')
axes[1].set_ylabel('Portfolio Value (₹1 invested)')
axes[1].legend(fontsize=7, ncol=2)
axes[1].xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

plt.tight_layout()
import os; os.makedirs('plots', exist_ok=True)
plt.savefig('plots/per_stock_equity_curves.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 6b. CAGR Bar Chart — All Stocks

# %%
cagr_series = summary['CAGR (%)'].sort_values(ascending=False)
colors = ['steelblue' if v > 0 else 'crimson' for v in cagr_series]

plt.figure(figsize=(18, 5))
plt.bar(cagr_series.index, cagr_series.values, color=colors)
plt.axhline(0, color='black', linewidth=0.8)
plt.axhline(bm_cagr * 100, color='orange', linewidth=1.5, linestyle='--',
            label=f'NIFTY B&H CAGR ({bm_cagr*100:.1f}%)')
plt.xticks(rotation=90, fontsize=8)
plt.title('Per-Stock CAGR — Mean Reversion Strategy')
plt.ylabel('CAGR (%)')
plt.legend()
plt.tight_layout()
plt.savefig('plots/per_stock_cagr.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 6c. Sharpe Ratio Bar Chart — All Stocks

# %%
sharpe_series = summary['Sharpe Ratio'].sort_values(ascending=False)
colors = ['steelblue' if v > 0.5 else ('gold' if v > 0 else 'crimson') for v in sharpe_series]

plt.figure(figsize=(18, 5))
plt.bar(sharpe_series.index, sharpe_series.values, color=colors)
plt.axhline(0,   color='black',  linewidth=0.8)
plt.axhline(0.5, color='green',  linewidth=1.2, linestyle='--', label='Sharpe = 0.5 (good threshold)')
plt.axhline(bm_sharpe, color='orange', linewidth=1.5, linestyle='--',
            label=f'NIFTY B&H Sharpe ({bm_sharpe:.2f})')
plt.xticks(rotation=90, fontsize=8)
plt.title('Per-Stock Sharpe Ratio — Mean Reversion Strategy')
plt.ylabel('Sharpe Ratio')
plt.legend()
plt.tight_layout()
plt.savefig('plots/per_stock_sharpe.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 6d. Drawdown Chart — Top 5 Stocks

# %%
top5 = summary.head(5).index.tolist()

plt.figure(figsize=(14, 5))
for stock in top5:
    eq  = results[stock]['equity']
    dd  = (eq - eq.cummax()) / eq.cummax()
    dd.plot(label=stock, linewidth=1)

plt.axhline(0, color='black', linewidth=0.8)
plt.title('Drawdown — Top 5 Stocks by Sharpe')
plt.ylabel('Drawdown')
plt.legend()
plt.tight_layout()
plt.savefig('plots/per_stock_drawdown.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 7. Overall Conclusion

# %%
avg_cagr   = summary['CAGR (%)'].mean()
avg_sharpe = summary['Sharpe Ratio'].mean()
good       = summary[(summary['Sharpe Ratio'] > 0.5) & (summary['CAGR (%)'] > 0)]
pct_good   = len(good) / len(STOCKS) * 100

print("=" * 60)
print("  OVERALL CONCLUSION")
print("=" * 60)
print(f"  Stocks analysed       : {len(STOCKS)}")
print(f"  Avg CAGR (strategy)   : {avg_cagr:.2f}%")
print(f"  Avg Sharpe (strategy) : {avg_sharpe:.3f}")
print(f"  Benchmark CAGR        : {bm_cagr*100:.2f}%")
print(f"  Benchmark Sharpe      : {bm_sharpe:.3f}")
print(f"  Stocks where strategy works well: {len(good)} ({pct_good:.0f}%)")
print()
if avg_sharpe > bm_sharpe:
    print("On average, mean reversion BEATS the benchmark on a risk-adjusted basis.")
else:
    print("On average, mean reversion TRAILS the benchmark on a risk-adjusted basis.")
print()
print(f"  Best stocks  : {summary.head(10).index.tolist()}")
print(f"  Worst stocks : {summary.tail(10).index.tolist()}")
print("=" * 60)

import os; os.makedirs('results', exist_ok=True)
summary.to_csv('results/per_stock_metrics.csv')
print("\nSaved to results/per_stock_metrics.csv")
# Out:
# ============================================================
#   OVERALL CONCLUSION
# ============================================================
#   Stocks analysed       : 49
#   Avg CAGR (strategy)   : -1.45%
#   Avg Sharpe (strategy) : -0.098
#   Benchmark CAGR        : 8.65%
#   Benchmark Sharpe      : 0.672
#   Stocks where strategy works well: 8 (16%)
#
# On average, mean reversion TRAILS the benchmark on a risk-adjusted basis.
#
#   Best stocks  : ['VEDL', 'ONGC', 'TATASTEEL', 'BHARTIARTL', 'COALINDIA', 'JSWSTEEL', 'HINDALCO', 'GRASIM', 'BPCL', 'ICICIBANK']
#   Worst stocks : ['TECHM', 'INFY', 'HCLTECH', 'NESTLEIND', 'APOLLOHOSP', 'BRITANNIA', 'SHREECEM', 'EICHERMOT', 'TCS', 'DRREDDY']
# ============================================================
#
# Saved to results/per_stock_metrics.csv
